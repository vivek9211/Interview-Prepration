# %%
data = [("United States", 9833517), ("Canada", 9984670), ("China", 9596961), ("Brazil", 8515767), ("Australia", 7692024)]
columns = ["country", "size"]
df_country_size = spark.createDataFrame(data, columns)
display(df_country_size)
